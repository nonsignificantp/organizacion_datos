# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from pathlib import Path
from matplotlib import pyplot as plt

# %%
clicks = Path('../data/raw/clicks.csv.gzip')
clicks = pd.read_csv(clicks, compression='gzip')

# %%
geom = clicks[['longitude','latitude']].apply(tuple, axis=1).map(Point)

# %%
gpd.GeoDataFrame({'geometry': geom}).to_file('puntos_uru.shp')

# %%
uruguay = gpd.read_file('../data/external/URY_adm1.shp')

# %%
-34.90328, -56.18816

# %%
1 - -1
# Out:
# 2

# %%
#lat
1.205689  - -34.90328
# Out:
# 36.108969

# %%
#long
1.070234 - -56.18816
# Out:
# 57.258394

# %%
clicks[[]]

# %%
rivera = (1.234142, 1.073781) # -30.9218777, -55.569526

# %%
artigas = (1.237861, 1.068549) # -30.4060304, -56.4969407

# %%
geom = clicks[['longitude','latitude']].apply(tuple, axis=1).map(Point)

# %%
clicks.loc[(clicks.latitude > 1.230) & (clicks.longitude > 1.066)]
# Out:
#        advertiser_id  action_id  source_id                   created  \
# 123                3        NaN          0  2019-03-07T23:52:22.193Z
# 380                3        NaN          0  2019-03-07T23:17:17.983Z
# 605                3        NaN          5  2019-03-07T23:16:30.681Z
# 1532               3        NaN          0  2019-03-08T01:30:18.890Z
# 1552               3        NaN          1  2019-03-08T01:35:51.633Z
# 2275               3        NaN          0  2019-03-08T01:31:15.205Z
# 2470               3        NaN          0  2019-03-08T09:12:03.025Z
# 2567               3        NaN          0  2019-03-08T10:27:25.983Z
# 3051               3        NaN          0  2019-03-08T06:10:28.934Z
# 3164               3        NaN          0  2019-03-08T06:19:25.871Z
# 6145               3        NaN          0  2019-03-09T05:47:46.291Z
# 7381               3        NaN          5  2019-03-09T07:15:33.319Z
# 10114              3        NaN          0  2019-03-07T23:52:24.996Z
# ...

# %%
fig, ax = plt.subplots(1,1,figsize=(20,20))
# uruguay.plot(ax=ax)
gpd.GeoDataFrame({'geometry': geom}).loc[].plot(ax=ax, color='red')
plt.show()
