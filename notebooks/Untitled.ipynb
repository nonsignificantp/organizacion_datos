# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from pathlib import Path
from matplotlib import pyplot as plt

# %%
clicks = Path('../data/raw/clicks.csv.gzip')
clicks = pd.read_csv(clicks, compression='gzip')

# %%
uruguay = gpd.read_file('../data/external/URY_adm1.shp')

# %%
-34.90328, -56.18816

# %%
1 - -1
# Out:
# 2

# %%
#lat
1.205689  - -34.90328
# Out:
# 36.108969

# %%
#long
1.070234 - -56.18816
# Out:
# 57.258394

# %%
clicks[[]]

# %%
geom = clicks[['longitude','latitude']].apply(tuple, axis=1).map(Point)

# %%
fig, ax = plt.subplots(1,1,figsize=(15,15))
# uruguay.plot(ax=ax)
gpd.GeoDataFrame({'geometry': geom}).plot(ax=ax, color='red')
plt.show()
